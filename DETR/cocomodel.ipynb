# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 참고 : https://www.youtube.com/watch?v=RkhXoj_Vvr4
#        https://www.kaggle.com/sreevishnudamodaran/vinbigdata-fusing-bboxes-coco-dataset

# %%
# %cd /content/gdrive/MyDrive/kaggle/Chest_Xray
# Out:
# /content/gdrive/MyDrive/kaggle/Chest_Xray

# %%
# %cd detr
# Out:
# /content/gdrive/MyDrive/kaggle/Chest_Xray/detr

# %%
ls -al
# Out:
# total 119
# drwx------ 2 root root  4096 Feb 23 07:39 .circleci/
# drwx------ 2 root root  4096 Feb 23 07:39 d2/
# drwx------ 2 root root  4096 Feb 23 07:39 datasets/
# -rw------- 1 root root   328 Nov 14 23:03 Dockerfile
# -rw------- 1 root root  6626 Nov 14 23:03 engine.py
# drwx------ 2 root root  4096 Feb 23 07:39 .github/
# -rw------- 1 root root   189 Nov 14 23:03 .gitignore
# -rw------- 1 root root  6265 Nov 14 23:03 hubconf.py
# drwx------ 2 root root  4096 Feb 25 04:48 .ipynb_checkpoints/
# -rw------- 1 root root 11354 Nov 14 23:03 LICENSE
# -rw------- 1 root root 11713 Feb 27 09:29 main.py
# drwx------ 2 root root  4096 Feb 23 07:39 models/
# drwx------ 2 root root  4096 Feb 25 04:48 myoutput/
# drwx------ 2 root root  4096 Feb 23 08:45 output/
# drwx------ 2 root root  4096 Feb 23 08:27 __pycache__/
# -rw------- 1 root root 11575 Nov 14 23:03 README.md
# -rw------- 1 root root   224 Nov 14 23:03 requirements.txt
# ...

# %%
cd datasets
# Out:
# /content/gdrive/MyDrive/kaggle/Chest_Xray/detr/datasets

# %%
ls -al
# Out:
# total 40
# -rw------- 1 root root 8735 Nov 14 23:03 coco_eval.py
# -rw------- 1 root root 3723 Nov 14 23:03 coco_panoptic.py
# -rw------- 1 root root 5253 Nov 14 23:03 coco.py
# -rw------- 1 root root 1100 Feb 24 05:55 __init__.py
# -rw------- 1 root root 1493 Nov 14 23:03 panoptic_eval.py
# drwx------ 2 root root 4096 Feb 23 08:25 __pycache__/
# -rw------- 1 root root 8524 Feb 25 01:24 transforms.py
# -rw------- 1 root root 5701 Feb 24 07:16 xray.py

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/kaggle/Chest_Xray/detr/datasets'

# %%
cd ..
# Out:
# /content/gdrive/MyDrive/kaggle/Chest_Xray/detr

# %%
import sys
sys.path.insert(0, '/content/gdrive/MyDrive/kaggle/Chest_Xray/detr')

# %%
sys.path
# Out:
# ['/content/gdrive/MyDrive/kaggle/Chest_Xray/detr',
#  '',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %% [markdown]
# 스크래치에서 train

# %%
# %run main.py --dataset_file xray --data_path ../dataset/coco/ --output_dir output
# Out:
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(aux_loss=True, backbone='resnet50', batch_size=2, bbox_loss_coef=5, clip_max_norm=0.1, coco_panoptic_path=None, data_path='../dataset/coco/', dataset_file='xray', dec_layers=6, device='cuda', dice_loss_coef=1, dilation=False, dim_feedforward=2048, dist_url='env://', distributed=False, dropout=0.1, enc_layers=6, eos_coef=0.1, epochs=300, eval=False, frozen_weights=None, giou_loss_coef=2, hidden_dim=256, lr=0.0001, lr_backbone=1e-05, lr_drop=200, mask_loss_coef=1, masks=False, nheads=8, num_queries=100, num_workers=2, output_dir='output', position_embedding='sine', pre_norm=False, remove_difficult=False, resume='', seed=42, set_cost_bbox=5, set_cost_class=1, set_cost_giou=2, start_epoch=0, weight_decay=0.0001, world_size=1)
# number of params: 41282579
# root ../dataset/coco
# loading annotations into memory...
# Done (t=0.15s)
# creating index...
# index created!
# root ../dataset/coco
# ...

# %% [markdown]
# backbone 네트워크 사용

# %%
# %run main.py --dataset_file xray --data_path ../dataset/coco/ --output_dir output --resume output/checkpoint.pth
# Out:
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(aux_loss=True, backbone='resnet50', batch_size=2, bbox_loss_coef=5, clip_max_norm=0.1, coco_panoptic_path=None, data_path='../dataset/coco/', dataset_file='xray', dec_layers=6, device='cuda', dice_loss_coef=1, dilation=False, dim_feedforward=2048, dist_url='env://', distributed=False, dropout=0.1, enc_layers=6, eos_coef=0.1, epochs=300, eval=False, frozen_weights=None, giou_loss_coef=2, hidden_dim=256, lr=0.0001, lr_backbone=1e-05, lr_drop=200, mask_loss_coef=1, masks=False, nheads=8, num_queries=100, num_workers=2, output_dir='output', position_embedding='sine', pre_norm=False, remove_difficult=False, resume='output/checkpoint.pth', seed=42, set_cost_bbox=5, set_cost_class=1, set_cost_giou=2, start_epoch=0, weight_decay=0.0001, world_size=1)
# number of params: 41282579
# root ../dataset/coco
# img_folder ../dataset/coco/train2017
# ann_file ../dataset/coco/train_annotations.json
# ...

# %% [markdown]
# Test

# %%
# %run test.py --data_path ../dataset/test/ --resume output/checkpoint0499.pth
# Out:
# image_paths 3000
# 1 processing...05fd4bbf127858eb83ae01cd454d3e2a.png
# 2 processing...4e60eda03b7df9196e6309009114f54b.png
# 3 processing...b0385734db3c516e5e9d43af7dcfbf3c.png
# 4 processing...6ae67e95de277c280873ec6a0dd3dc01.png
# 5 processing...b381d2dc6d77140e137a70933adf2f23.png
# 6 processing...be39af57fa823e11f4559891d1d6ea1f.png
# 7 processing...2b7ee30a6af65e9d2915764004122b36.png
# 8 processing...0e302ce9dc207afa54c8661ebdfc9051.png
# 9 processing...9ab7362cc2e62924da202b728de69a59.png
# 10 processing...5f187acbe31f6335db2d8ec41c2815b5.png
# 11 processing...d5bce42a9f926d6fd3b968164bab99b2.png
# 12 processing...931dc77300612101a84eff6070ca270a.png
# Processing...931dc77300612101a84eff6070ca270a.png (0.049s)
# 13 processing...cabaca5197759010eda73ad3e3f372d2.png
# 14 processing...35360687c230a5851d43ee95597d7b71.png
# 15 processing...2e2f4e832dc3bd12ddd8d405cbf7fdf5.png
# 16 processing...a8738fcce7411391f6c9804a7458d45e.png
# ...

# %% [markdown]
# Example

# %%
# %run test.py --data_path ../dataset/test/ --resume myoutput/checkpoint.pth
# Out:
# image_paths 3000
# 1 processing...7b60d69158c11381cad26574b327c723.png
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F0112CC3590>
# Processing...7b60d69158c11381cad26574b327c723.png (0.055s)
# Avg. Time: 0.055s
#                            image_id       PredictionString
# 0  7b60d69158c11381cad26574b327c723  1 0.3 576 196 347 537
